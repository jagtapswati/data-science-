# %% [markdown]
# <a href="https://colab.research.google.com/github/jagtapswati/data-science-/blob/main/day2pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload=files.upload()
# Out:
#      <input type="file" id="files-833d39f2-84da-449b-b229-1f98a646135d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-833d39f2-84da-449b-b229-1f98a646135d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("imdbtop.csv")

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df['Genre'].value_counts()
# Out:
# Drama                         58
# Drama, Romance                26
# Comedy, Drama                 24
# Crime, Drama, Thriller        22
# Action, Adventure, Sci-Fi     21
#                               ..
# Crime, Film-Noir, Thriller     1
# Drama, Film-Noir, Romance      1
# Drama, History, Romance        1
# Adventure, Horror, Sci-Fi      1
# Comedy, Music, Musical         1
# Name: Genre, Length: 172, dtype: int64

# %%
df['Certificate'].value_counts()
# Out:
# U           183
# A           174
# UA          142
# R           131
# PG-13        38
# PG           19
# G             9
# Passed        9
# Approved      6
# TV-PG         1
# U/A           1
# GP            1
# Name: Certificate, dtype: int64

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   714.000000  714.000000  7.140000e+02
# mean      7.937115   77.158263  3.561348e+05
# std       0.293278   12.401144  3.539011e+05
# min       7.600000   28.000000  2.522900e+04
# 25%       7.700000   70.000000  9.600975e+04
# 50%       7.900000   78.000000  2.366025e+05
# 75%       8.100000   86.000000  5.077922e+05
# max       9.300000  100.000000  2.343110e+06

# %%
filt=df['Genre'].str.contains('Romance',na=False)

# %%
filt.value_counts()
# Out:
# False    626
# True      88
# Name: Genre, dtype: int64

# %%
df.loc[filt]
# Out:
#                                            Poster_Link  \
# 11   https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 26   https://m.media-amazon.com/images/M/MV5BYmJmM2...
# 45   https://m.media-amazon.com/images/M/MV5BM2FhYj...
# 50   https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# ..                                                 ...
# 965  https://m.media-amazon.com/images/M/MV5BNmRiZD...
# 967  https://m.media-amazon.com/images/M/MV5BNTliYT...
# 971  https://m.media-amazon.com/images/M/MV5BMTY5Nj...
# 975  https://m.media-amazon.com/images/M/MV5BMjE0OD...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                       Series_Title Released_Year Certificate  Runtime  \
# 11                    Forrest Gump          1994          UA  142 min
# 26                 La vita è bella          1997           U  116 min
# 45           Nuovo Cinema Paradiso          1988           U  155 min
# ...

# %%
df['Runtime']
# Out:
# 0      142 min
# 1      175 min
# 2      152 min
# 3      202 min
# 4       96 min
#         ...
# 990    157 min
# 991    144 min
# 992     78 min
# 994     87 min
# 997    118 min
# Name: Runtime, Length: 714, dtype: object

# %%
df['Runtime']=df['Runtime'].apply(lambda x: x.split(" "))

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate     Runtime  \
# 0  The Shawshank Redemption          1994           A  [142, min]
# 1             The Godfather          1972           A  [175, min]
# 2           The Dark Knight          2008          UA  [152, min]
# 3    The Godfather: Part II          1974           A  [202, min]
# 4              12 Angry Men          1957           U   [96, min]
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['Runtime']=df['Runtime'].apply(lambda x: x[0])

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime  \
# 0  The Shawshank Redemption          1994           A     142
# 1             The Godfather          1972           A     175
# 2           The Dark Knight          2008          UA     152
# 3    The Godfather: Part II          1974           A     202
# 4              12 Angry Men          1957           U      96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 94.8+ KB

# %%
df['Runtime']=df['Runtime'].astype('int64')

# %%
df.describe()
# Out:
#           Runtime  IMDB_Rating  Meta_score   No_of_Votes
# count  714.000000   714.000000  714.000000  7.140000e+02
# mean   123.715686     7.937115   77.158263  3.561348e+05
# std     25.887535     0.293278   12.401144  3.539011e+05
# min     72.000000     7.600000   28.000000  2.522900e+04
# 25%    104.250000     7.700000   70.000000  9.600975e+04
# 50%    120.000000     7.900000   78.000000  2.366025e+05
# 75%    136.000000     8.100000   86.000000  5.077922e+05
# max    238.000000     9.300000  100.000000  2.343110e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    int64
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 94.8+ KB

# %%
filt1=(df['Runtime']>=180) & (df['IMDB_Rating']>=8)

# %%
df[filt1]
# Out:
#                                            Poster_Link  \
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 25   https://m.media-amazon.com/images/M/MV5BMTUxMz...
# 31   https://m.media-amazon.com/images/M/MV5BOWE4ZD...
# 59   https://m.media-amazon.com/images/M/MV5BMTc5MD...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 147  https://m.media-amazon.com/images/M/MV5BMjIxMj...
# 247  https://m.media-amazon.com/images/M/MV5BNDYxNW...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 278  https://m.media-amazon.com/images/M/MV5BNDhmNT...
# 300  https://m.media-amazon.com/images/M/MV5BNjgxY2...
# 314  https://m.media-amazon.com/images/M/MV5BYjUyZW...
# 374  https://m.media-amazon.com/images/M/MV5BYmVjND...
# 383  https://m.media-amazon.com/images/M/MV5BZjk3YT...
# 397  https://m.media-amazon.com/images/M/MV5BNzZmMj...
# ...

# %%
filt1.value_counts()
# Out:
# False    693
# True      21
# dtype: int64

# %%
len(df[filt1])
# Out:
# 21
