# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatripendhari/DataScience_Training/blob/main/Day02_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-7111d200-df7e-4fdd-844c-49927db64e8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7111d200-df7e-4fdd-844c-49927db64e8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df1=pd.read_csv("MallCustomer.csv")

# %%
df1
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df1.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df1.shape
# Out:
# (200, 5)

# %%
df1.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df1['CustomerID']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 200, dtype: int64

# %%
df1['Genre']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df1.isna().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
type(df1['Genre'])
# Out:
# pandas.core.series.Series

# %%
df1.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df1['Genre'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
df1.iloc[0]
# Out:
# CustomerID                   1
# Genre                     Male
# Age                         19
# Annual Income (k$)          15
# Spending Score (1-100)      39
# Name: 0, dtype: object

# %%
df1.iloc[0:11,0:2]
# Out:
#     CustomerID   Genre
# 0            1    Male
# 1            2    Male
# 2            3  Female
# 3            4  Female
# 4            5  Female
# 5            6  Female
# 6            7  Female
# 7            8  Female
# 8            9    Male
# 9           10  Female
# 10          11    Male

# %%
df1.loc[0:11,['CustomerID','Genre']]
# Out:
#     CustomerID   Genre
# 0            1    Male
# 1            2    Male
# 2            3  Female
# 3            4  Female
# 4            5  Female
# 5            6  Female
# 6            7  Female
# 7            8  Female
# 8            9    Male
# 9           10  Female
# 10          11    Male
# 11          12  Female

# %%
df1.loc[0:5,'Genre':'Annual Income (k$)']
# Out:
#     Genre  Age  Annual Income (k$)
# 0    Male   19                  15
# 1    Male   21                  15
# 2  Female   20                  16
# 3  Female   23                  16
# 4  Female   31                  17
# 5  Female   22                  17

# %%
people={
    "first":["aryan","uday","divij"],
    "last":["sonawane","talele","kulkarni"],
    "email":["aryans.nsk@gmail.com","ut@gmail.com","macenth@gmail.com"]
}

# %%
people["email"]
# Out:
# ['aryans.nsk@gmail.com', 'ut@gmail.com', 'macenth@gmail.com']

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.set_index('email',inplace=True)  #used to set an index, returns in bold, inplace is immutble
df
# Out:
#                       first      last
# email
# aryans.nsk@gmail.com  aryan  sonawane
# ut@gmail.com           uday    talele
# macenth@gmail.com     divij  kulkarni

# %%
df.index
# Out:
# Index(['aryans.nsk@gmail.com', 'ut@gmail.com', 'macenth@gmail.com'], dtype='object', name='email')

# %%
df.reset_index(inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#                   email  first      last
# 2     macenth@gmail.com  divij  kulkarni
# 1          ut@gmail.com   uday    talele
# 0  aryans.nsk@gmail.com  aryan  sonawane

# %%
df.drop('email',axis=1,inplace=True)

# %%
df
# Out:
#    first      last
# 0  aryan  sonawane
# 1   uday    talele
# 2  divij  kulkarni

# %%
df.drop(2,axis=0,inplace=True)

# %%
df
# Out:
#    first      last
# 0  aryan  sonawane
# 1   uday    talele

# %%
df2={'email':['ratspawar@gmail.com','dips@gmail.com','tans@gmail.com'],
     'first':['ratnali','deepali','tanmayi'],
     'last':['pawar','khajure','shete']}

# %%
pd.DataFrame(df2)
# Out:
#                  email    first     last
# 0  ratspawar@gmail.com  ratnali    pawar
# 1       dips@gmail.com  deepali  khajure
# 2       tans@gmail.com  tanmayi    shete

# %%
df2
# Out:
# {'email': ['ratspawar@gmail.com', 'dips@gmail.com', 'tans@gmail.com'],
#  'first': ['ratnali', 'deepali', 'tanmayi'],
#  'last': ['pawar', 'khajure', 'shete']}

# %%
df2=pd.DataFrame(df2)
df2
# Out:
#                  email    first     last
# 0  ratspawar@gmail.com  ratnali    pawar
# 1       dips@gmail.com  deepali  khajure
# 2       tans@gmail.com  tanmayi    shete

# %%
df=df.append(df2,ignore_index=True)
df
# Out:
# <ipython-input-75-cfb9280262ee>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)
#       first      last                email
# 0     aryan  sonawane                  NaN
# 1      uday    talele                  NaN
# 2   deepali   khajure                  NaN
# 3   tanmayi     shete                  NaN
# 4   ratnali     pawar                  NaN
# 5   deepali   khajure                  NaN
# 6   tanmayi     shete                  NaN
# 7   ratnali     pawar                  NaN
# 8   deepali   khajure                  NaN
# 9   tanmayi     shete                  NaN
# 10  ratnali     pawar  ratspawar@gmail.com
# 11  deepali   khajure       dips@gmail.com
# 12  tanmayi     shete       tans@gmail.com

# %%
filt=df['last']=='shete'

# %%
#df[filt]
# Out:
#       first   last           email
# 3   tanmayi  shete             NaN
# 6   tanmayi  shete             NaN
# 9   tanmayi  shete             NaN
# 12  tanmayi  shete  tans@gmail.com

# %%
filt=df['first']=='sonawane'

# %%
df[filt]
# Out:
#        first      last                email
# 0   sonawane  sonawane                  NaN
# 1   sonawane    talele                  NaN
# 2   sonawane   khajure                  NaN
# 3   sonawane     shete                  NaN
# 4   sonawane     pawar                  NaN
# 5   sonawane   khajure                  NaN
# 6   sonawane     shete                  NaN
# 7   sonawane     pawar                  NaN
# 8   sonawane   khajure                  NaN
# 9   sonawane     shete                  NaN
# 10  sonawane     pawar  ratspawar@gmail.com
# 11  sonawane   khajure       dips@gmail.com
# 12  sonawane     shete       tans@gmail.com

# %%
filt=df1['Genre']=='Female'

# %%
df1[filt]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 191         192  Female   32                 103                      69
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
#
# [112 rows x 5 columns]

# %%
filt=df

# %%
flit2 = (df1['Genre']=='Female') & (df1['Spending Score (1-100)']>=75)

# %%
df1[flit2]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 3             4  Female   23                  16                      77
# 5             6  Female   22                  17                      76
# 7             8  Female   23                  18                      94
# 11           12  Female   35                  19                      99
# 13           14  Female   24                  20                      77
# 19           20  Female   35                  23                      98
# 29           30  Female   23                  29                      87
# 35           36  Female   21                  33                      81
# 39           40  Female   20                  37                      75
# 125         126  Female   31                  70                      77
# 135         136  Female   29                  73                      88
# 143         144  Female   32                  76                      87
# ...

# %%
len(flit2)
# Out:
# 200

# %%
flit2.value_counts()
# Out:
# False    175
# True      25
# dtype: int64

# %%
f = (df1['Age']>=30) & (df1['Spending Score (1-100)']>=75)

# %%
f
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195     True
# 196    False
# 197    False
# 198    False
# 199     True
# Length: 200, dtype: bool

# %%
len(df1[f])
# Out:
# 25

# %%
rich=(df1['Age']>=39) & (df1['Spending Score (1-100)']>=75)

# %%
df1[rich].count()
# Out:
# CustomerID                4
# Genre                     4
# Age                       4
# Annual Income (k$)        4
# Spending Score (1-100)    4
# dtype: int64

# %%
df1[rich]
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 123         124  Male   39                  69                      91
# 127         128  Male   40                  71                      95
# 131         132  Male   39                  71                      75
# 151         152  Male   39                  78                      88

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-b92a9474-3891-4031-87c3-494517910c50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b92a9474-3891-4031-87c3-494517910c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df4=pd.read_csv("imdb_top.csv")

# %%
df4
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df4.shape
# Out:
# (1000, 16)

# %%
df4.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df4.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df4.isna()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
df4.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df4.dropna(inplace=True)

# %%
df4
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df4['Genre'].value_counts()
# Out:
# Drama                         58
# Drama, Romance                26
# Comedy, Drama                 24
# Crime, Drama, Thriller        22
# Action, Adventure, Sci-Fi     21
#                               ..
# Crime, Film-Noir, Thriller     1
# Drama, Film-Noir, Romance      1
# Drama, History, Romance        1
# Adventure, Horror, Sci-Fi      1
# Comedy, Music, Musical         1
# Name: Genre, Length: 172, dtype: int64

# %%
df4['Genre'].value_counts().head(10)
# Out:
# Drama                           58
# Drama, Romance                  26
# Comedy, Drama                   24
# Crime, Drama, Thriller          22
# Action, Adventure, Sci-Fi       21
# Animation, Adventure, Comedy    20
# Biography, Drama, History       20
# Crime, Drama                    19
# Comedy, Drama, Romance          19
# Action, Crime, Drama            18
# Name: Genre, dtype: int64

# %%
df4['Certificate'].value_counts()
# Out:
# U           183
# A           174
# UA          142
# R           131
# PG-13        38
# PG           19
# G             9
# Passed        9
# Approved      6
# TV-PG         1
# U/A           1
# GP            1
# Name: Certificate, dtype: int64

# %%
df4.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   714.000000  714.000000  7.140000e+02
# mean      7.937115   77.158263  3.561348e+05
# std       0.293278   12.401144  3.539011e+05
# min       7.600000   28.000000  2.522900e+04
# 25%       7.700000   70.000000  9.600975e+04
# 50%       7.900000   78.000000  2.366025e+05
# 75%       8.100000   86.000000  5.077922e+05
# max       9.300000  100.000000  2.343110e+06

# %%
filt4=df4['Genre'].str.contains('Romance',na=False)

# %% [markdown]
# filt4.value_counts()

# %%
filt4.value_counts()
# Out:
# False    626
# True      88
# Name: Genre, dtype: int64

# %%
df4.loc[filt4]
# Out:
#                                            Poster_Link  \
# 11   https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 26   https://m.media-amazon.com/images/M/MV5BYmJmM2...
# 45   https://m.media-amazon.com/images/M/MV5BM2FhYj...
# 50   https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# ..                                                 ...
# 965  https://m.media-amazon.com/images/M/MV5BNmRiZD...
# 967  https://m.media-amazon.com/images/M/MV5BNTliYT...
# 971  https://m.media-amazon.com/images/M/MV5BMTY5Nj...
# 975  https://m.media-amazon.com/images/M/MV5BMjE0OD...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                       Series_Title Released_Year Certificate  Runtime  \
# 11                    Forrest Gump          1994          UA  142 min
# 26                 La vita è bella          1997           U  116 min
# 45           Nuovo Cinema Paradiso          1988           U  155 min
# ...

# %%
df4['Runtime']
# Out:
# 0      [142]
# 1      [175]
# 2      [152]
# 3      [202]
# 4       [96]
#        ...
# 990    [157]
# 991    [144]
# 992     [78]
# 994     [87]
# 997    [118]
# Name: Runtime, Length: 714, dtype: object

# %%
df4['Runtime']=df4['Runtime'].apply(lambda x: x.split(" "))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-192-f9f4e22f8636> in <cell line: 1>()
# ----> 1 df4['Runtime']=df4['Runtime'].apply(lambda x: x.split(" "))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# ...

# %%
df4.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate     Runtime  \
# 0  The Shawshank Redemption          1994           A  [142, min]
# 1             The Godfather          1972           A  [175, min]
# 2           The Dark Knight          2008          UA  [152, min]
# 3    The Godfather: Part II          1974           A  [202, min]
# 4              12 Angry Men          1957           U   [96, min]
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df4['Runtime']=df4['Runtime'].apply(lambda x: x[0])

# %%
df4.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime  \
# 0  The Shawshank Redemption          1994           A     142
# 1             The Godfather          1972           A     175
# 2           The Dark Knight          2008          UA     152
# 3    The Godfather: Part II          1974           A     202
# 4              12 Angry Men          1957           U      96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 111.0+ KB

# %%
df4['Runtime']=df4['Runtime'].astype('int64')

# %%
df4.describe()
# Out:
#           Runtime  IMDB_Rating  Meta_score   No_of_Votes
# count  714.000000   714.000000  714.000000  7.140000e+02
# mean   123.715686     7.937115   77.158263  3.561348e+05
# std     25.887535     0.293278   12.401144  3.539011e+05
# min     72.000000     7.600000   28.000000  2.522900e+04
# 25%    104.250000     7.700000   70.000000  9.600975e+04
# 50%    120.000000     7.900000   78.000000  2.366025e+05
# 75%    136.000000     8.100000   86.000000  5.077922e+05
# max    238.000000     9.300000  100.000000  2.343110e+06

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    int64
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 111.0+ KB

# %%
filt5=(df4['Runtime']>=180) & (df4['IMDB_Rating']>=8)

# %%
df4[filt5]
# Out:
#                                            Poster_Link  \
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 25   https://m.media-amazon.com/images/M/MV5BMTUxMz...
# 31   https://m.media-amazon.com/images/M/MV5BOWE4ZD...
# 59   https://m.media-amazon.com/images/M/MV5BMTc5MD...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 147  https://m.media-amazon.com/images/M/MV5BMjIxMj...
# 247  https://m.media-amazon.com/images/M/MV5BNDYxNW...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 278  https://m.media-amazon.com/images/M/MV5BNDhmNT...
# 300  https://m.media-amazon.com/images/M/MV5BNjgxY2...
# 314  https://m.media-amazon.com/images/M/MV5BYjUyZW...
# 374  https://m.media-amazon.com/images/M/MV5BYmVjND...
# 383  https://m.media-amazon.com/images/M/MV5BZjk3YT...
# 397  https://m.media-amazon.com/images/M/MV5BNzZmMj...
# ...

# %%
filt5.value_counts()
# Out:
# False    693
# True      21
# dtype: int64

# %%
len(df4[filt5])
# Out:
# 21
